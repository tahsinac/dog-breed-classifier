# %% [markdown]
# Imports

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# # path = "drive/MyDrive/645-project-data/" # Google Drive path
path = "data/"  # Local path

# %%
# Check GPU
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)

if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

# Check RAM
from psutil import virtual_memory

ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Mon Apr  4 02:43:41 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.image as mpimg
from IPython.display import display, Image
import os
import pathlib
import glob
import shutil
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot

# %% [markdown]
# Loading the Data

# %%
# !mkdir data

# %%
# !ls
# Out:
# data  sample_data

# %%
# %%capture
# !unzip train.zip -d data/train

# %%
labels = pd.read_csv(path + "labels.csv")
labels["id"] = [fname + ".jpg" for fname in labels["id"]]
print(f"There are a total of {labels.describe().iloc[1, :][0]} labeled images")
print(f"There are {labels.describe().iloc[1, :][1]} different dog breeds in this dataset")
# Out:
# There are a total of 10222 labeled images
# There are 120 different dog breeds in this dataset

# %%
labels["breed"].value_counts().plot.bar(figsize=(30, 5))
plt.show()

# %%
sample_imgs = []
for index, row in labels.sample(12).iterrows():
    sample_imgs.append((row["id"], row["breed"]))

fig = plt.figure(figsize=(20, 10))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    img = mpimg.imread(path + "train/" + sample_imgs[i-1][0])
    # img = mpimg.imread(path + "/" + sample_imgs[i-1][0])
    fig.add_subplot(rows, columns, i).title.set_text(sample_imgs[i-1][1])
    plt.imshow(img)
plt.tight_layout()
plt.show()

# %% [markdown]
# Data Augmentation & Preprocessing

# %%
BATCH_SIZE = 64
IMG_SIZE = 224

# Train and validation generators

# Ensures the data is preprocessed exactly how the data in the pretrained model was
datagen = ImageDataGenerator(preprocessing_function = tf.keras.applications.vgg16.preprocess_input, validation_split=0.25)

train_generator = datagen.flow_from_dataframe(
                        dataframe = labels,
                        directory = path + "train/",
                        x_col="id",
                        y_col="breed",
                        subset="training",
                        batch_size=BATCH_SIZE,
                        seed=42,
                        shuffle=True,
                        class_mode="sparse",
                        color_mode="rgb",
                        target_size=(IMG_SIZE, IMG_SIZE))

validation_generator = datagen.flow_from_dataframe(
                        dataframe = labels,
                        directory = path + "train/",
                        x_col="id",
                        y_col="breed",
                        subset="validation",
                        batch_size=BATCH_SIZE,
                        seed=42,
                        shuffle=True, 
                        class_mode="sparse",
                        color_mode="rgb",
                        target_size=(IMG_SIZE, IMG_SIZE))
# Out:
# Found 7667 validated image filenames belonging to 120 classes.
# Found 2555 validated image filenames belonging to 120 classes.

# %%
class_names = [name for name in train_generator.class_indices.keys()]
images, labels = next(iter(train_generator))

fig = plt.figure(figsize=(22, 5))

for i in np.arange(20):
    ax = fig.add_subplot(2, 10, i + 1, xticks=[], yticks=[])
    plt.imshow(images[i])
    ax.set_title(class_names[int(labels[i])])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Modelling

# %%
# Using the keras Sequential API (another way of doing it would be the Functional API)

# Overall model
vgg16_model = tf.keras.Sequential()

# Retrieve the pre-trained model
pretrained_model = tf.keras.applications.VGG16(include_top=False,
                   input_shape=(IMG_SIZE, IMG_SIZE, 3),
                   weights='imagenet')

# Freeze all the layers in the pretrained model
for layer in pretrained_model.layers:
    layer.trainable=False

# Un-freeze the BatchNorm layers because we want them to be trained (helps with overfitting)
for layer in pretrained_model.layers:
    if "BatchNormalization" in layer.__class__.__name__:
        layer.trainable = True
        
vgg16_model.add(pretrained_model) # Add the pre-trained model to the model

# Modify the 'top layer' parameters 
vgg16_model.add(tf.keras.layers.BatchNormalization())
vgg16_model.add(tf.keras.layers.GlobalAveragePooling2D())
vgg16_model.add(tf.keras.layers.Dropout(0.5))
vgg16_model.add(tf.keras.layers.Dense(1024, activation='relu'))
vgg16_model.add(tf.keras.layers.Dropout(0.5))
vgg16_model.add(tf.keras.layers.Dense(256, activation='relu'))
vgg16_model.add(tf.keras.layers.Dropout(0.5))
vgg16_model.add(tf.keras.layers.Dense(len(class_names), activation='softmax'))
vgg16_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  batch_normalization (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 256)               262400
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 120)               30840
#
# =================================================================
# Total params: 15,535,288
# Trainable params: 819,576
# Non-trainable params: 14,715,712
# _________________________________________________________________

# %%
# Names for model to be saved
model_name_it = "dog_breed_classifier_vgg16.h5"
model_name_ft = "dog_breed_classifier_vgg16.h5"

# Early stopping for when scores plateau
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

# Checkpoints to save model periodically
monitor_it = tf.keras.callbacks.ModelCheckpoint(model_name_it, monitor='val_loss',
                                                verbose=0,save_best_only=True,
                                                save_weights_only=False,
                                                mode='min')

monitor_ft = tf.keras.callbacks.ModelCheckpoint(model_name_ft, monitor='val_loss',
                                                verbose=0,save_best_only=True,
                                                save_weights_only=False,
                                                mode='min')

# Learning rate decay scheduler
def scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch != 0:
        lr = lr / 2

    return lr

lr_schedule = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=0)

# %%
 # Optimizer to be used - other options are Adam and SGD
optimizer = tf.keras.optimizers.RMSprop(learning_rate=1e-3, rho=0.9)

# Compile 
vgg16_model.compile(optimizer=optimizer,
                     loss='sparse_categorical_crossentropy',
                     metrics=['accuracy'])

history_it = vgg16_model.fit(train_generator, epochs=50, verbose = 1, 
                             callbacks=[early_stop, monitor_it, lr_schedule], 
                             validation_data=(validation_generator))
# Out:
# Epoch 1/50
# 120/120 [==============================] - 61s 423ms/step - loss: 4.3467 - accuracy: 0.0745 - val_loss: 3.0212 - val_accuracy: 0.3483 - lr: 0.0010
# Epoch 2/50
# 120/120 [==============================] - 41s 337ms/step - loss: 3.0801 - accuracy: 0.2333 - val_loss: 2.0198 - val_accuracy: 0.4959 - lr: 0.0010
# Epoch 3/50
# 120/120 [==============================] - 41s 337ms/step - loss: 2.4914 - accuracy: 0.3265 - val_loss: 1.6252 - val_accuracy: 0.5703 - lr: 0.0010
# Epoch 4/50
# 120/120 [==============================] - 40s 333ms/step - loss: 2.1821 - accuracy: 0.4007 - val_loss: 1.4520 - val_accuracy: 0.5957 - lr: 0.0010
# Epoch 5/50
# 120/120 [==============================] - 40s 333ms/step - loss: 2.0251 - accuracy: 0.4355 - val_loss: 1.3518 - val_accuracy: 0.6117 - lr: 0.0010
# Epoch 6/50
# 120/120 [==============================] - 40s 333ms/step - loss: 1.9145 - accuracy: 0.4621 - val_loss: 1.2832 - val_accuracy: 0.6309 - lr: 0.0010
# Epoch 7/50
# 120/120 [==============================] - 40s 335ms/step - loss: 1.8328 - accuracy: 0.4866 - val_loss: 1.2440 - val_accuracy: 0.6317 - lr: 0.0010
# Epoch 8/50
# 120/120 [==============================] - 40s 333ms/step - loss: 1.7776 - accuracy: 0.5005 - val_loss: 1.2134 - val_accuracy: 0.6458 - lr: 0.0010
# Epoch 9/50
# 120/120 [==============================] - 40s 334ms/step - loss: 1.6852 - accuracy: 0.5149 - val_loss: 1.1870 - val_accuracy: 0.6489 - lr: 0.0010
# Epoch 10/50
# 120/120 [==============================] - 40s 335ms/step - loss: 1.6568 - accuracy: 0.5269 - val_loss: 1.1813 - val_accuracy: 0.6497 - lr: 0.0010
# Epoch 11/50
# 120/120 [==============================] - 40s 334ms/step - loss: 1.5722 - accuracy: 0.5486 - val_loss: 1.1365 - val_accuracy: 0.6614 - lr: 5.0000e-04
# Epoch 12/50
# 120/120 [==============================] - 40s 332ms/step - loss: 1.5419 - accuracy: 0.5529 - val_loss: 1.1251 - val_accuracy: 0.6626 - lr: 5.0000e-04
# Epoch 13/50
# 120/120 [==============================] - 41s 339ms/step - loss: 1.5149 - accuracy: 0.5708 - val_loss: 1.1185 - val_accuracy: 0.6732 - lr: 5.0000e-04
# Epoch 14/50
# 120/120 [==============================] - 40s 334ms/step - loss: 1.4670 - accuracy: 0.5726 - val_loss: 1.1131 - val_accuracy: 0.6681 - lr: 5.0000e-04
# Epoch 15/50
# 120/120 [==============================] - 40s 332ms/step - loss: 1.4738 - accuracy: 0.5794 - val_loss: 1.1162 - val_accuracy: 0.6701 - lr: 5.0000e-04
# Epoch 16/50
# 120/120 [==============================] - 40s 332ms/step - loss: 1.4251 - accuracy: 0.5881 - val_loss: 1.1017 - val_accuracy: 0.6791 - lr: 5.0000e-04
# Epoch 17/50
# 120/120 [==============================] - 40s 330ms/step - loss: 1.4010 - accuracy: 0.5918 - val_loss: 1.1031 - val_accuracy: 0.6716 - lr: 5.0000e-04
# Epoch 18/50
# 120/120 [==============================] - 40s 334ms/step - loss: 1.4020 - accuracy: 0.5936 - val_loss: 1.0983 - val_accuracy: 0.6744 - lr: 5.0000e-04
# Epoch 19/50
# 120/120 [==============================] - 40s 331ms/step - loss: 1.3778 - accuracy: 0.6055 - val_loss: 1.0970 - val_accuracy: 0.6798 - lr: 5.0000e-04
# Epoch 20/50
# 120/120 [==============================] - 40s 333ms/step - loss: 1.3685 - accuracy: 0.6069 - val_loss: 1.0995 - val_accuracy: 0.6744 - lr: 5.0000e-04
# Epoch 21/50
# 120/120 [==============================] - 40s 330ms/step - loss: 1.3443 - accuracy: 0.6083 - val_loss: 1.0861 - val_accuracy: 0.6795 - lr: 2.5000e-04
# Epoch 22/50
# 120/120 [==============================] - 40s 335ms/step - loss: 1.2881 - accuracy: 0.6231 - val_loss: 1.0785 - val_accuracy: 0.6806 - lr: 2.5000e-04
# Epoch 23/50
# 120/120 [==============================] - 40s 333ms/step - loss: 1.3396 - accuracy: 0.6198 - val_loss: 1.0825 - val_accuracy: 0.6795 - lr: 2.5000e-04
# Epoch 24/50
# 120/120 [==============================] - 40s 330ms/step - loss: 1.2767 - accuracy: 0.6287 - val_loss: 1.0789 - val_accuracy: 0.6744 - lr: 2.5000e-04
# Epoch 25/50
# 120/120 [==============================] - 40s 332ms/step - loss: 1.3135 - accuracy: 0.6197 - val_loss: 1.0760 - val_accuracy: 0.6775 - lr: 2.5000e-04
# Epoch 26/50
# 120/120 [==============================] - 40s 333ms/step - loss: 1.2642 - accuracy: 0.6289 - val_loss: 1.0744 - val_accuracy: 0.6818 - lr: 2.5000e-04
# Epoch 27/50
# 120/120 [==============================] - 41s 341ms/step - loss: 1.2970 - accuracy: 0.6220 - val_loss: 1.0741 - val_accuracy: 0.6830 - lr: 2.5000e-04
# Epoch 28/50
# 120/120 [==============================] - 41s 343ms/step - loss: 1.2518 - accuracy: 0.6348 - val_loss: 1.0755 - val_accuracy: 0.6755 - lr: 2.5000e-04
# Epoch 29/50
# 120/120 [==============================] - 41s 342ms/step - loss: 1.2611 - accuracy: 0.6382 - val_loss: 1.0722 - val_accuracy: 0.6838 - lr: 2.5000e-04
# Epoch 30/50
# 120/120 [==============================] - 41s 338ms/step - loss: 1.2507 - accuracy: 0.6360 - val_loss: 1.0789 - val_accuracy: 0.6783 - lr: 2.5000e-04
# Epoch 31/50
# 120/120 [==============================] - 41s 338ms/step - loss: 1.2136 - accuracy: 0.6405 - val_loss: 1.0746 - val_accuracy: 0.6779 - lr: 1.2500e-04
# Epoch 32/50
# 120/120 [==============================] - 40s 337ms/step - loss: 1.2198 - accuracy: 0.6385 - val_loss: 1.0726 - val_accuracy: 0.6763 - lr: 1.2500e-04
# Epoch 33/50
# 120/120 [==============================] - 40s 336ms/step - loss: 1.2326 - accuracy: 0.6404 - val_loss: 1.0742 - val_accuracy: 0.6806 - lr: 1.2500e-04
# Epoch 34/50
# 120/120 [==============================] - 40s 333ms/step - loss: 1.2042 - accuracy: 0.6413 - val_loss: 1.0702 - val_accuracy: 0.6818 - lr: 1.2500e-04
# Epoch 35/50
# 120/120 [==============================] - 40s 335ms/step - loss: 1.2262 - accuracy: 0.6424 - val_loss: 1.0694 - val_accuracy: 0.6830 - lr: 1.2500e-04
# Epoch 36/50
# 120/120 [==============================] - 40s 331ms/step - loss: 1.2287 - accuracy: 0.6430 - val_loss: 1.0690 - val_accuracy: 0.6841 - lr: 1.2500e-04
# Epoch 37/50
# 120/120 [==============================] - 40s 332ms/step - loss: 1.2016 - accuracy: 0.6458 - val_loss: 1.0688 - val_accuracy: 0.6826 - lr: 1.2500e-04
# Epoch 38/50
# 120/120 [==============================] - 40s 332ms/step - loss: 1.1947 - accuracy: 0.6458 - val_loss: 1.0675 - val_accuracy: 0.6857 - lr: 1.2500e-04
# Epoch 39/50
# 120/120 [==============================] - 40s 331ms/step - loss: 1.1911 - accuracy: 0.6442 - val_loss: 1.0694 - val_accuracy: 0.6822 - lr: 1.2500e-04
# Epoch 40/50
# 120/120 [==============================] - 40s 330ms/step - loss: 1.1938 - accuracy: 0.6459 - val_loss: 1.0684 - val_accuracy: 0.6830 - lr: 1.2500e-04
# Epoch 41/50
# 120/120 [==============================] - 40s 330ms/step - loss: 1.1828 - accuracy: 0.6502 - val_loss: 1.0675 - val_accuracy: 0.6849 - lr: 6.2500e-05
# Epoch 42/50
# 120/120 [==============================] - 41s 343ms/step - loss: 1.1993 - accuracy: 0.6502 - val_loss: 1.0665 - val_accuracy: 0.6873 - lr: 6.2500e-05
# Epoch 43/50
# 120/120 [==============================] - 41s 338ms/step - loss: 1.1756 - accuracy: 0.6559 - val_loss: 1.0670 - val_accuracy: 0.6861 - lr: 6.2500e-05
# Epoch 44/50
# 120/120 [==============================] - 40s 336ms/step - loss: 1.1654 - accuracy: 0.6525 - val_loss: 1.0669 - val_accuracy: 0.6865 - lr: 6.2500e-05
# Epoch 45/50
# 120/120 [==============================] - 41s 338ms/step - loss: 1.1847 - accuracy: 0.6488 - val_loss: 1.0665 - val_accuracy: 0.6849 - lr: 6.2500e-05
# Epoch 46/50
# 120/120 [==============================] - 40s 336ms/step - loss: 1.1851 - accuracy: 0.6507 - val_loss: 1.0678 - val_accuracy: 0.6869 - lr: 6.2500e-05
# Epoch 47/50
# 120/120 [==============================] - 41s 341ms/step - loss: 1.1681 - accuracy: 0.6594 - val_loss: 1.0689 - val_accuracy: 0.6877 - lr: 6.2500e-05
# Epoch 48/50
# 120/120 [==============================] - 41s 337ms/step - loss: 1.1382 - accuracy: 0.6553 - val_loss: 1.0668 - val_accuracy: 0.6845 - lr: 6.2500e-05
# Epoch 49/50
# 120/120 [==============================] - 41s 340ms/step - loss: 1.1421 - accuracy: 0.6567 - val_loss: 1.0658 - val_accuracy: 0.6865 - lr: 6.2500e-05
# Epoch 50/50
# 120/120 [==============================] - 41s 339ms/step - loss: 1.1744 - accuracy: 0.6545 - val_loss: 1.0659 - val_accuracy: 0.6845 - lr: 6.2500e-05

# %%
plt.figure()
plt.plot(history_it.history["val_loss"], label = "Val loss")
plt.plot(history_it.history["loss"], label = "Train loss")
plt.legend()
plt.show()

plt.figure()
plt.plot(history_it.history["val_accuracy"], label = "Val accuracy")
plt.plot(history_it.history["accuracy"], label = "Accuracy")
plt.legend()

# %%
from keras.models import load_model

model = load_model('./dog_breed_classifier_vgg16.h5')

# %%
model.get_layer('vgg16').trainable = True

#Review the layer names 
for layer in model.get_layer('vgg16').layers:
  print(layer.name)
# Out:
# input_1
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# block3_conv2
# block3_conv3
# block3_pool
# block4_conv1
# block4_conv2
# block4_conv3
# block4_pool
# block5_conv1
# block5_conv2
# block5_conv3
# block5_pool

# %%
#Fine tune, the layers by unfreezing the conv3 layers.
for layer in model.get_layer('vgg16').layers:
  if "conv3" in layer.name:
    pass
  else:
    layer.trainable = False

# %%
optimizer = tf.keras.optimizers.RMSprop(learning_rate=1e-3, rho=0.9)

# Re-compiling the model
model.compile(optimizer=optimizer,
                    loss='sparse_categorical_crossentropy',
                    metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  batch_normalization (BatchN  (None, 7, 7, 512)        2048
#  ormalization)
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 256)               262400
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 120)               30840
#
# =================================================================
# Total params: 15,535,288
# Trainable params: 6,129,272
# Non-trainable params: 9,406,016
# _________________________________________________________________

# %%
# Training the model with the pre-trained weights unfrozen

model_name_it = "dog_breed_classifier_vgg16_9_unfrozen.h5"
model_name_ft = "dog_breed_classifier_vgg16_9_unfrozen.h5"

early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)


monitor_it = tf.keras.callbacks.ModelCheckpoint(model_name_it, monitor='val_loss',
                                                verbose=0,save_best_only=True,
                                                save_weights_only=False,
                                                mode='min')

monitor_ft = tf.keras.callbacks.ModelCheckpoint(model_name_ft, monitor='val_loss',
                                                verbose=0,save_best_only=True,
                                                save_weights_only=False,
                                                mode='min')

def scheduler(epoch, lr):
    if epoch % 5 == 0 and epoch!= 0:
        lr = lr/2

    return lr

lr_schedule = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=0)

history_it = model.fit(train_generator, epochs=20, verbose = 1,
                              callbacks= [early_stop, monitor_it, lr_schedule],
                              validation_data = (validation_generator))
# Out:
# Epoch 1/20
# 120/120 [==============================] - 43s 343ms/step - loss: 4.7633 - accuracy: 0.0158 - val_loss: 18.2816 - val_accuracy: 0.0117 - lr: 0.0010
# Epoch 2/20
# 120/120 [==============================] - 40s 331ms/step - loss: 4.5471 - accuracy: 0.0291 - val_loss: 7.5563 - val_accuracy: 0.0270 - lr: 0.0010
# Epoch 3/20
# 120/120 [==============================] - 40s 331ms/step - loss: 4.2402 - accuracy: 0.0473 - val_loss: 15.7623 - val_accuracy: 0.0286 - lr: 0.0010
# Epoch 4/20
# 120/120 [==============================] - 40s 336ms/step - loss: 3.9627 - accuracy: 0.0720 - val_loss: 3.8021 - val_accuracy: 0.1018 - lr: 0.0010
# Epoch 5/20
# 120/120 [==============================] - 40s 334ms/step - loss: 3.6962 - accuracy: 0.1055 - val_loss: 7.9940 - val_accuracy: 0.0697 - lr: 0.0010
# Epoch 6/20
# 120/120 [==============================] - 41s 337ms/step - loss: 3.3133 - accuracy: 0.1647 - val_loss: 3.1692 - val_accuracy: 0.1859 - lr: 5.0000e-04
# Epoch 7/20
# 120/120 [==============================] - 40s 334ms/step - loss: 3.0991 - accuracy: 0.1947 - val_loss: 2.9198 - val_accuracy: 0.2450 - lr: 5.0000e-04
# Epoch 8/20
# 120/120 [==============================] - 40s 331ms/step - loss: 2.9106 - accuracy: 0.2238 - val_loss: 2.9293 - val_accuracy: 0.2450 - lr: 5.0000e-04
# Epoch 9/20
# 120/120 [==============================] - 40s 334ms/step - loss: 2.7590 - accuracy: 0.2568 - val_loss: 11.1006 - val_accuracy: 0.1659 - lr: 5.0000e-04
# Epoch 10/20
# 120/120 [==============================] - 39s 327ms/step - loss: 2.6299 - accuracy: 0.2842 - val_loss: 3.2116 - val_accuracy: 0.2344 - lr: 5.0000e-04
# Epoch 11/20
# 120/120 [==============================] - 40s 333ms/step - loss: 2.3461 - accuracy: 0.3463 - val_loss: 2.4835 - val_accuracy: 0.3346 - lr: 2.5000e-04
# Epoch 12/20
# 120/120 [==============================] - 40s 335ms/step - loss: 2.2359 - accuracy: 0.3695 - val_loss: 2.3629 - val_accuracy: 0.3550 - lr: 2.5000e-04
# Epoch 13/20
# 120/120 [==============================] - 40s 336ms/step - loss: 2.1272 - accuracy: 0.3867 - val_loss: 2.3620 - val_accuracy: 0.3558 - lr: 2.5000e-04
# Epoch 14/20
# 120/120 [==============================] - 40s 334ms/step - loss: 2.0359 - accuracy: 0.4110 - val_loss: 2.2409 - val_accuracy: 0.4016 - lr: 2.5000e-04
# Epoch 15/20
# 120/120 [==============================] - 40s 336ms/step - loss: 1.9376 - accuracy: 0.4320 - val_loss: 2.4160 - val_accuracy: 0.3476 - lr: 2.5000e-04
# Epoch 16/20
# 120/120 [==============================] - 40s 333ms/step - loss: 1.7841 - accuracy: 0.4675 - val_loss: 2.1614 - val_accuracy: 0.4110 - lr: 1.2500e-04
# Epoch 17/20
# 120/120 [==============================] - 41s 338ms/step - loss: 1.7278 - accuracy: 0.4788 - val_loss: 2.1686 - val_accuracy: 0.4114 - lr: 1.2500e-04
# Epoch 18/20
# 120/120 [==============================] - 40s 333ms/step - loss: 1.6674 - accuracy: 0.4912 - val_loss: 2.1281 - val_accuracy: 0.4290 - lr: 1.2500e-04
# Epoch 19/20
# 120/120 [==============================] - 40s 336ms/step - loss: 1.5886 - accuracy: 0.5098 - val_loss: 2.2756 - val_accuracy: 0.4063 - lr: 1.2500e-04
# Epoch 20/20
# 120/120 [==============================] - 40s 329ms/step - loss: 1.5493 - accuracy: 0.5251 - val_loss: 2.3661 - val_accuracy: 0.3914 - lr: 1.2500e-04

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
